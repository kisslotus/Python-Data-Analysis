# %%
import numpy as np
import pandas as pd
from pandas import Series
import matplotlib.pyplot as plt

# %%
s1 = Series(np.random.randn(10)).cumsum()

# %%
s1.plot(grid = True, label = 'S1',style="--")
plt.legend()
