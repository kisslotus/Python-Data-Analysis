# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
a = [1, 2, 3]
plt.plot(a)

# %%
b = [4, 5, 6]

# %%
plt.plot(a, b)

# %%
plt.plot(a, b,"g*")

# %%
plt.plot(a, b,"r--")

# %%
t = np.arange(0.0, 2.0, 0.1)

# %%
t.size
# Out:
# 20

# %%
s = np.sin(t*np.pi)

# %%
s.size
# Out:
# 20

# %%
plt.plot(t,s,'r',label = "a")
plt.plot(t*2,s,'g',label = "b")
plt.xlabel('this is x')
plt.ylabel('this is y')
plt.title('this is a demo')
plt.legend()
