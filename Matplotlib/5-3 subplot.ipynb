# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.subplot(2, 1, 1)
plt.plot([1,2,3],[1,2,3])
plt.subplot(2, 1, 2)
plt.plot([1,2,3],[1,4,9])

# %%
plt.subplot(2, 2, 1)
plt.plot([1,2,3],[1,2,3])
plt.subplot(2, 2, 2)
plt.plot([1,2,3],[1,4,9])
plt.subplot(2, 2, 3)
plt.plot([1,2,3],[1,4,9],"*")
plt.subplot(2, 2, 4)
plt.plot([1,2,3],[1,2,3],"r")

# %%
a = plt.subplots(2,2)

# %%
type(a)
# Out:
# tuple

# %%
a[0]
