# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame

# %%
import seaborn as sns

# %%
s1 = Series(np.random.randn(100))

# %%
plt.hist(s1)
# Out:
# (array([  7.,  27., 104., 171., 295., 230., 115.,  44.,   4.,   3.]),
#  array([-3.32788875, -2.61782316, -1.90775756, -1.19769197, -0.48762637,
#          0.22243922,  0.93250481,  1.64257041,  2.352636  ,  3.0627016 ,
#          3.77276719]),
#  <a list of 10 Patch objects>)

# %%
s1.plot(kind='kde')

# %%
sns.distplot(s1, hist=True, kde=True)
